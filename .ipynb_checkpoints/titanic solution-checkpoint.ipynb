# %% [markdown]
# # Importing Required Libraries

# %% [markdown]
# # Use the Titanic dataset to build a model that predicts whether apassenger on the Titanic survived or not. This is a classic beginnerproject with readily available data.

# %% [markdown]
# # The dataset typically used for this project contains informationabout individual passengers, such as their age, gender, ticketclass, fare, cabin, and whether or not they survived.

# %% [markdown]
# # Import required Libraries for Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.ensemble import RandomForestClassifier
import scipy
from scipy.stats import zscore
from scipy.stats import boxcox

# %% [markdown]
# # Loading the File into Pandas DataFrame Structure

# %%
df=pd.read_csv('tested.csv',header=0)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df=pd.DataFrame(df)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# # Checking the Null values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# # As from the above Data we have 86 Null values(Empty Values) In Age Column and 327 Null values in Cabin Column

# %%
import missingno as msn
msn.matrix(df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # Filling Age With Average Age Values

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %% [markdown]
# # Checking Null values in Age Again

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
msn.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# # Filling the Fare NUll values with fare median values

# %%
df['Fare'].fillna(df['Fare'].median(),inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex       Age  SibSp  \
# 0                                Kelly, Mr. James    male  34.50000      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.00000      1
# 2                       Myles, Mr. Thomas Francis    male  62.00000      0
# 3                                Wirz, Mr. Albert    male  27.00000      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.00000      1
# ..                                            ...     ...       ...    ...
# ...

# %%
df['Cabin'].isnull().sum()
# Out:
# 327

# %%
df['Cabin'].unique()
# Out:
# array([nan, 'B45', 'E31', 'B57 B59 B63 B66', 'B36', 'A21', 'C78', 'D34',
#        'D19', 'A9', 'D15', 'C31', 'C23 C25 C27', 'F G63', 'B61', 'C53',
#        'D43', 'C130', 'C132', 'C101', 'C55 C57', 'B71', 'C46', 'C116',
#        'F', 'A29', 'G6', 'C6', 'C28', 'C51', 'E46', 'C54', 'C97', 'D22',
#        'B10', 'F4', 'E45', 'E52', 'D30', 'B58 B60', 'E34', 'C62 C64',
#        'A11', 'B11', 'C80', 'F33', 'C85', 'D37', 'C86', 'D21', 'C89',
#        'F E46', 'A34', 'D', 'B26', 'C22 C26', 'B69', 'C32', 'B78',
#        'F E57', 'F2', 'A18', 'C106', 'B51 B53 B55', 'D10 D12', 'E60',
#        'E50', 'E39 E41', 'B52 B54 B56', 'C39', 'B24', 'D28', 'B41', 'C7',
#        'D40', 'D38', 'C105'], dtype=object)

# %% [markdown]
# # As from the above there are 327 null values present in Cabin

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  418.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   12.634534    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   23.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   30.272590    0.000000
# 75%    1204.750000    1.000000    3.000000   35.750000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  418.000000
# mean     0.392344   35.576535
# std      0.981429   55.850103
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.471875
# max      9.000000  512.329200

# %% [markdown]
# # Clearly Fare and Age have Outliers in Them

# %% [markdown]
# # Univariate Analysis for Checking the Outliers

# %%
plt.boxplot(df['Age'])
plt.xlabel('Age')
plt.title("Chcking Outliers Presence in Age Column")
plt.show()

# %% [markdown]
# # Outliers are present in Age

# %%
plt.boxplot(df['Fare'])
plt.title("Checking Outlers Presence in Fare")
plt.xlabel("Fare")
plt.show()

# %% [markdown]
# # Outliers Present in Fare Column

# %%
plt.boxplot(df['Pclass'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25022762700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x250227ba8b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25022762460>],
#  'medians': [<matplotlib.lines.Line2D at 0x2502275b070>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2502275b1c0>],
#  'means': []}

# %% [markdown]
# # No Whiskers Present in Pclass

# %%
sns.pairplot(df)

# %%
plt.scatter(df['Age'],df['Fare'])
plt.title("Scatterplot between Age and Fare")
plt.xlabel('Age')
plt.ylabel("Fare")
plt.show()

# %%
plt.scatter(df['Age'],df['PassengerId'])

# %%
sns.countplot(x='Survived',hue='Sex',data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Embarked',data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
plt.bar(df.columns,df.isnull().sum())
# Out:
# <BarContainer object of 12 artists>

# %%
sns.jointplot(x=df['Fare'],y=df['Age'],kind='kde')
